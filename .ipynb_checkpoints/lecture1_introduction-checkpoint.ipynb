# %% [markdown]
# <table border=0 width="100%"><tr><td><p align="left"><img src="..\img\logo.png" align="left" width=300></p></td><td><font size=5><B> 金融数据分析与可视化导论(郑海超)</B></font></td></tr></table>

# %% [markdown]
# # 内容
# - 课程规划与教学资源
# - 数据分析中对工具的用和造
# - 案例：国家经济数据分析
# - AI辅助做数据分析
# - 课堂练习：基于寒武纪和贵州茅台的股价数据做数据分析
# - 课堂练习：Basics of AI Python Coding
# - 课后学习安排

# %% [markdown]
# # 教学规划

# %% [markdown]
# [金融数据分析与可视化教学规划](https://ai4science.feishu.cn/wiki/BUecwZxMxi3mNakEIrPcsQO1n0f)

# %% [markdown]
# # 教学资源
# - **超星课堂**：[金融数据分析与可视化（郑海超）](https://i.chaoxing.com/)
# - 参考教材:Python数据分析
# - 飞书文档[金融数据分析与AI产品开发](https://ai4science.feishu.cn/wiki/ObCtwy9Eti0ug2k2GOZcNu4mnvd)
# - 超星课程（学院教师共建课程）[金融数据分析与可视化](https://www.xueyinonline.com/detail/244599764)
# - github课程资料 [financial_data_analysis](https://github.com/haichaozheng/financial_data_analysis)

# %% [markdown]
# 如果大家要使用github的资料（方便下载课程资料）
# 基本的操作：
# - 下载安装git [git for Windows](https://git-scm.com/download/win)
# - git clone（首次下载github项目代码） - git clone https://github.com/haichaozheng/financial_data_analysis.git
# - git pull （方便后续更新代码） - 进入项目文件夹，git pull origin master[也可能是git pull origin main]
#
# [git clone github项目代码](https://ai4science.feishu.cn/wiki/Q9UAwV9hii42AXkkF3DctKLLncf)

# %% [markdown]
# # 教学交流
# - 办公时间：周四上午10:00-11:30（通博楼D407，郑海超）
# - 课程QQ群：1028316296
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 课程考核
# - 平时成绩（包括出勤，默认满勤，我会随机选择学生分享问题） - 使用我们课程的“幸运儿大转盘”
# - 个人项目（期末提交）

# %% [markdown]
# # 数据分析中对工具的用和造
# ![image.png](attachment:image.png)

# %% [markdown]
# 上述流程仅仅考虑了做数据分析的流程，没有考虑去创造新的数据集和工具。
#
# **特别强调：**
# - 我们可以应用已有的数据和工具做分析
# - 我们也可以创建新的数据集（甚至仿真数据集）
# - 我们也可以创建新的数据分析工具
#
# 可以**用**，也可以**造**！

# %% [markdown]
# # 案例：国家经济数据分析
# - [国家统计局](https://data.stats.gov.cn/easyquery.htm?cn=A01)
#
# > - 注册后可以下载数据；
# > - 这里我们关注月度数据

# %% [markdown]
# ## 确定数据分析研究问题
# - 选择你关注的方向
# - 确定具体可落实的研究问题

# %% [markdown]
# ### 话题选择：国家财政收入与支出

# %% [markdown]
# [正确解读财政收入和财政支出](https://www.stats.gov.cn/zs/tjws/zytjzbqs/czsyhczzc/202502/t20250226_1958807.html)
# - 财政收入的规模和增速直接反映了国民经济运行的状况及质量
# - 由于财政收入按现价计算，随着价格总水平的变动，财政收入绝对量也会发生相应的变化
# - 从世界范围看，各国财政支出规模不断增长是一种普遍现象
# - 在中国“以收定支、量入为出”的预算管理模式下，财政支出规模总体仍由财政收入规模决定。即使进行反周期调控，财政赤字也不能过大，财政支出仍要以财政收入为基础来确定

# %% [markdown]
# 问题：在国家财政收入与支出的分析中，你关注哪些具体问题？

# %% [markdown]
# ## 下载数据并读取数据

# %% [markdown]
# ### 读取数据

# %% [markdown]
# ### 理解数据含义
#
#  国家财政收入累计增长(%)是什么意思？如何计算的？

# %% [markdown]
# ### 分析：国家财政收入累计值(亿元)的增长趋势

# %% [markdown]
# #### 问题讨论
# - 为什么数据呈现锯齿状？
# - 有什么办法可以更直观地展示吗？

# %% [markdown]
# #### 问题：为什么前几年12月份的数据没有了？

# %% [markdown]
# #### 问题：用累积数据还是不太直观，有什么办法可以更直观地展示吗？

# %% [markdown]
# ## 结果解释与报告
#
# 可以和coze 空间的智能体一起写作
# [coze 空间](https://space.coze.cn/)

# %% [markdown]
# [数据分析报告](https://space.coze.cn/s/mTasmOcEuz8/)

# %% [markdown]
# 根据这这个数据和数据分析结果图片，写一个简短的分析报告，包括数据的基本信息、分析方法、分析结果和结论。
#
# https://space.coze.cn/task/7539771490451964212

# %% [markdown]
# ## Why Nations Succeed and Fail
#
# ### [原则2](https://economicprinciples.org/)
#
# * Education
# * Innovation & Technology
# * Infrastructure & Investment
# * Economic Output
# * Expected Growth (Big Economic Cycle)
# * Trade
# * Military Strength
# * Financial Center
# * Reserve Currency Status
#
#
# CHINA—KEY DRIVERS OF OUR COUNTRY POWER SCORE
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 终身成长
#
# ![image.png](attachment:image.png)

# %%
##### 如何看待课程考核？

# %% [markdown]
# # 数据分析在经济领域的更多应用(选讲）
#
# ## 数据分析类型
# - 描述性和报告分析：报表、可视化
# - 预测分析与解释性研究： 机器学习、深度学习、实验研究、仿真

# %% [markdown]
# ## 应用数据分析反洗钱
# - [Detecting Money Laundering and Terrorist Financing
#  via Data Mining](https://dl.acm.org/doi/pdf/10.1145/986213.986239)
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 财经领域中中更多的数据分析应用
# - 金融理论实证研究（金融统计）-课程会少量涉及
# - **量化交易** （通过数量化方法作出投资决策，使用计算机技术完成交易指令）

# %% [markdown]
# # AI与大模型对数据分析的价值
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 大数据、大语言模型驱动的决策范式转变
#
# 信息情景、决策流程、决策主体、理念假设
#
# ![image.png](attachment:image.png)
#
# 陈国青,曾大军,卫强,张明月,郭迅华.大数据环境下的决策范式转变与使能创新[J].管理世界,2020,36(02):95-105+220.DOI:10.19744/j.cnki.11-1235/f.2020.0023.

# %% [markdown]
# ### 大语言模型与数据分析
# - 模型成本降低
# - 模型性能提升：长链条推理能力提升

# %% [markdown]
# # 使用AI工具辅助数据分析

# %% [markdown]
# - [coze 空间](https://space.coze.cn/)
# - [智普清言](https://chatglm.cn/main/gdetail/65a265419d72d299a9230616?t=1755490948206&lang=zh)

# %% [markdown]
# # 讨论：有了AI工具，我们还需要学习编程吗？

# %% [markdown]
# 1. 逻辑思维与问题解决能力。
# 2. 深入理解技术原理和工具，更好地应用AI工具。

# %% [markdown]
# # 本课程和大模型方向的AI的关系：
# 1. 课程内容涉及大模型基础原理及其应用。
# 2. 鼓励学生随时与大模型互动，提升问题解决能力。
# 3. 如果没有合适的AI工具，尝试自己去开发一个。
# 4. 要人在回路，做好检查和审核等工作。

# %% [markdown]
# # 课堂练习：基于寒武纪和贵州茅台的股价数据做数据分析
# - 基于寒武纪和贵州茅台的股价数据，提出你感兴趣的问题（cn_stock数据文件夹)
# - 尝试应用AI工具做数据分析 （例如coze 空间、智能体工具）
# - 分析结果
# - **课堂分享交流**

# %% [markdown]
# # 课堂练习：AI python编程基础

# %% [markdown]
# AI is the new electricity and will transform and improve nearly all areas of human lives.

# %% [markdown]
# 大家根据自己 python基础，选择学习
# 这里推荐一个基础课程：
# [Basics of AI Python Coding](https://learn.deeplearning.ai/courses/ai-python-for-beginners/lesson/rgkn7/how-to-succeed-in-coding)
#
# 我们可以打开一个jupyter notebook，尝试复习一下python基础：
# Lesson_6.ipynb

# %% [markdown]
# # 课后自学
# - 准备开发环境
# - 初步体验AI辅助编程
# - https://github.com/linkhui/BuildAICareer 资料学习

# %% [markdown]
# ## 准备开发环境 （鼓励Anaconda+Trae），方便基础工具包和虚拟环境工具管理
#
# 开发工具准备：
# - 安装**Anaconda**或者直接安装python
# - 安装集成开发环境**Trae**或者VS code或者pycharm
#
# 开发工具与开发环境
#
# python
# - https://www.anaconda.com/download/
# - https://www.python.org/downloads/windows/
#
# integrated development tools
# - https://www.trae.ai/?from=aiug.cn
# - https://code.visualstudio.com/
# - https://www.jetbrains.com/pycharm/
# - https://jupyter.org/install

# %% [markdown]
# ##  初步体验AI辅助编程
# - 安装使用trae（推荐）
# - 或者在visual studio code 中使用copilot 插件（例如trae AI、或则CodeGeeX）

# %% [markdown]
# 例如：应用CodeGeeX插件
# - try copilot in VS code (Visual Studio Code)
# - install [CodeGeeX](https://codegeex.cn/downloadGuide)

# %% [markdown]
# [CodeGeeX使用说明](https://zhipu-ai.feishu.cn/wiki/CuvxwUDDqiErQUkFO2Tc4walnZY)

# %% [markdown]
# ## 资料学习
#
# [学习资料](https://home-wordpress.deeplearning.ai/wp-content/uploads/2022/10/eBook-How-to-Build-a-Career-in-AI.pdf)
#
# <img src = "../img/build_creer_in_AI.png" width = 600>
#
# https://github.com/linkhui/BuildAICareer

# %% [markdown]
# 完成阅读
# - Introduction
# - Chapter 1
#
#
# **下周我们邀请同学做分享交流**

# %% [markdown]
# # 课后作业
# **利用今天课程的数据(national data)和AI工具，提出有趣的问题，并做探索分析**
# - 提出问题
# - 应用AI工具做数据分析
# - 撰写报告（pdf）（包括题目、摘要、正文、附录-你选择的AI工具，以及应用这个工具的工作过程介绍与截图）
#
# 提交作业：
# - 在线提交：http://swufe.fanya.chaoxing.com/portal
# - 截止日期：2025年9月17日晚上8点
# - 提交PDF报告，命名为“你的学号+姓名.pdf”
#
# **下周我们邀请同学分享其完成作业的过程**

# %% [markdown]
# # 下周教学内容：Copilot coding
